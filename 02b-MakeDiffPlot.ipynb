# %%
from pyscripts.plotting_utils import *

# %%
figure_dir = '/ocean/projects/cis250004p/josephdb/Deep-MMS/figures/difference_figures/'
if not os.path.isdir(figure_dir):
    os.makedirs(figure_dir, exist_ok=True)

# %%
#meta_data = [parse_best_models(f'best_model_list_{basem}.txt') for basem in ['X013-1', 'X013-2', 'X013-3', 'X013-4']]
#determine_comparisons('X013-2')

# %%
#compare no regularization against the others
prefs = ['OX_', 'DA_', 'DA_stretch_', 'CR_', 'BR_', 'HIV1p_']
ceils = [1.5, 1.5, 1.5, 3.0, 3.0, 3.0]

for pref, ceil in zip(prefs, ceils):
    for i in ['1', '3', '4']:
        #try:
        fig, log = violin_difference_plot(f'{pref}X013-2', f'{pref}X013-{i}', pref, show=True, ceil=ceil, figure_dir='figures/difference_figures/')
        #except:
        #    print(f"Problem on comparison of {pref}X013-2 against {pref}X013-{i}...")#raise Exception()
# Out:
# [(1999,), (1991,), (1978,), (1987,), (1959,), (1972,), (1975,)]
# [(1999,), (1988,), (1972,), (1985,), (1954,), (1970,), (1975,)]
# [(1997,), (2000,), (2000,), (2000,), (2000,), (2000,), (2000,)]
# [(1999,), (2000,), (2000,), (2000,), (2000,), (2000,), (2000,)]
# [(1999,), (1996,), (1964,), (1987,), (1971,), (1972,), (1835,)]
# [(2000,), (1990,), (1958,), (1987,), (1971,), (1969,), (1844,)]
# [(1939,), (1999,), (1996,), (1987,), (1964,), (1961,), (1951,), (1967,)]
# [(1926,), (1955,), (1996,), (1987,), (1964,), (1961,), (1951,), (1948,)]
# [(1953,), (1999,), (1999,), (1993,), (1983,), (1964,), (1982,), (1961,)]
# [(1953,), (1951,), (1964,), (1993,), (1983,), (1964,), (1946,), (1944,)]
# [(1953,), (1979,), (1994,), (1953,), (1963,), (1965,), (1952,), (1964,)]
# [(1937,), (1930,), (1955,), (1954,), (1961,), (1970,), (1961,), (1945,)]
# [(21781,), (21842,), (21820,), (21776,), (21747,), (21740,), (21705,), (21674,)]
# ...

# %%
from pyscripts.plotting_utils import *
_ = violin_difference_plot(f'DA_X013-2', f'DA_stretch_X013-2', "DA_",
                           show=True, ceil=10, figure_dir='./')
# Out:
# self=[array([5.76437982, 5.57663193, 5.50977861, ..., 5.01277504, 5.30157757,
#        5.35519299]), array([5.67872245, 5.71347353, 5.66366424, ..., 6.07172514, 5.84018507,
#        6.06599538]), array([10.24417622, 10.17178166,  8.91178074, ...,  5.68902372,
#         5.58160255,  5.800202  ]), array([6.31007887, 6.46327618, 6.38375427, ..., 6.62688392, 6.96075879,
#        6.7295837 ]), array([6.61824824, 6.58342152, 6.53513611, ..., 5.42880985, 5.85046427,
#        5.7795198 ]), array([6.17356212, 6.07730668, 6.25663234, ..., 5.66485911, 6.1984809 ,
#        5.89053784]), array([6.04983589, 6.12834466, 6.22136006, ..., 5.90395674, 5.70874964,
#        5.88173874]), array([6.19577124, 5.8463325 , 6.03953237, ..., 5.7370785 , 5.9123671 ,
#        5.8795705 ])]
# self=[array([-4.70090517, -4.79013978, -5.31334876, ..., -5.54799227,
#        -6.05616949, -6.40950221]), array([-5.37027049, -5.32289925, -5.8246093 , ..., -5.98899679,
# ...
